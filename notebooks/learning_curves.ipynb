# %%
import matplotlib.pyplot as plt
import pandas as pd

vgg_history = pd.read_csv(r'../logs/history_vgg_2009_150_64.csv')
inception_history = pd.read_csv(r'../logs/history_inception_2009_150_64.csv')
resnet_history = pd.read_csv(r'../logs/history_resnet_2009_150_64.csv')

vgg2_history = pd.read_csv(r'../logs/history_vgg_2009_150_128.csv')
inception2_history = pd.read_csv(r'../logs/history_inception_2009_150_128.csv')
resnet2_history = pd.read_csv(r'../logs/history_resnet_2009_150_128.csv')

models = [vgg2_history, inception2_history, resnet2_history]

# %%
train_colors = ['crimson', 'mediumseagreen', 'royalblue']
val_colors = ['lightcoral', 'lightgreen', 'lightskyblue']

# %%
for i, history in enumerate(models):
    plt.figure(figsize=(5, 5))
    # plt.ylim([0.075, 0.275])
    # plt.xlim([0, 51])
    plt.plot(range(1, 51), history['loss'], label='Zbiór treningowy', color=train_colors[i])
    plt.plot(range(1, 51), history['val_loss'], label='Zbiór walidacyjny', color=val_colors[i])
    # plt.grid()
    plt.legend(loc='upper right')
    # plt.title('Model loss')
    plt.ylabel('Strata kontrastowa')
    plt.xlabel('Epoka')
    plt.show()

    plt.figure(figsize=(5, 5))
    # plt.ylim([0.5, 1])
    # plt.xlim([0, 51])
    plt.plot(range(1, 51), history['accuracy'], label='Zbiór treningowy', color=train_colors[i])
    plt.plot(range(1, 51), history['val_accuracy'], label='Zbiór walidacyjny', color=val_colors[i])
    # plt.grid()
    plt.legend(loc='lower right')
    # plt.title('Model accuracy')
    plt.ylabel('Dokładność [%]')
    plt.xlabel('Epoka')
    plt.show()

# %%
plt.figure(figsize=(5, 5))
for i, history in enumerate(models):
    plt.ylim([0.075, 0.275])
    # plt.xlim([0, 51])
    plt.plot(range(1, 51), history['loss'], color=train_colors[i])
    # plt.plot(range(1, 51), history['val_loss'], color=val_colors[i])
    # plt.grid()
    # plt.legend(loc='upper right')
    # plt.title('Model loss')
    plt.ylabel('Strata kontrastowa')
    plt.xlabel('Epoka')
plt.legend(['VGG-16', 'Inception-v3', 'ResNet-50'])
plt.show()

plt.figure(figsize=(5, 5))
for i, history in enumerate(models):
    plt.ylim([0.075, 0.275])
    # plt.xlim([0, 51])
    # plt.plot(range(1, 51), history['loss'], color=train_colors[i])
    plt.plot(range(1, 51), history['val_loss'], color=val_colors[i])
    # plt.grid()
    # plt.legend(loc='upper right')
    # plt.title('Model loss')
    plt.ylabel('Strata kontrastowa')
    plt.xlabel('Epoka')
plt.legend(['VGG-16', 'Inception-v3', 'ResNet-50'])
plt.show()

# %%
plt.figure(figsize=(5, 5))
for i, history in enumerate(models):
    plt.ylim([0, 1])
    # plt.xlim([0, 51])
    plt.plot(range(1, 51), history['accuracy'], label='Zbiór treningowy', color=train_colors[i])
    # plt.plot(range(1, 51), history['val_accuracy'], label='Zbiór walidacyjny', color=val_colors[i])
    # plt.grid()
    # plt.legend(loc='lower right')
    # plt.title('Model accuracy')
    plt.ylabel('Dokładność [%]')
    plt.xlabel('Epoka')
plt.legend(['VGG-16', 'Inception-v3', 'ResNet-50'], loc='lower right')
plt.show()

plt.figure(figsize=(5, 5))
for i, history in enumerate(models):
    plt.ylim([0, 1])
    # plt.xlim([0, 51])
    # plt.plot(range(1, 51), history['accuracy'], label='Zbiór treningowy', color=train_colors[i])
    plt.plot(range(1, 51), history['val_accuracy'], label='Zbiór walidacyjny', color=val_colors[i])
    # plt.grid()
    # plt.legend(loc='lower right')
    # plt.title('Model accuracy')
    plt.ylabel('Dokładność [%]')
    plt.xlabel('Epoka')
plt.legend(['VGG-16', 'Inception-v3', 'ResNet-50'], loc='lower right')
plt.show()
