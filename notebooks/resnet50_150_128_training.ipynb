# %%
import os
import sys
sys.path.append('../')
from facerec.dataset_generator import DataGenerator
from facerec.siamese_models import get_siamese_model, train_model

# %%
IMGS_DIR = r'../data/faces/'
PAIRS_DIR = r'../data/pairs/'
TRAIN_POSITIVE_PAIRS_DIR = os.path.join(PAIRS_DIR, 'train_positive_pairs.csv')
TRAIN_NEGATIVE_PAIRS_DIR = os.path.join(PAIRS_DIR, 'train_negative_pairs.csv')

SEED = 80808
BATCH_SIZE = 32
INPUT_SHAPE = (150, 150, 3)

train_data = DataGenerator(
    positive_pairs_path=TRAIN_POSITIVE_PAIRS_DIR,
    negative_pairs_path=TRAIN_NEGATIVE_PAIRS_DIR,
    images_path=IMGS_DIR,
    input_shape=INPUT_SHAPE,
    batch_size=BATCH_SIZE,
    seed=SEED,
    shuffle=True,
    debug=True
)

VAL_POSITIVE_PAIRS_DIR = os.path.join(PAIRS_DIR, 'val_positive_pairs.csv')
VAL_NEGATIVE_PAIRS_DIR = os.path.join(PAIRS_DIR, 'val_negative_pairs.csv')

val_data = DataGenerator(
    positive_pairs_path=VAL_POSITIVE_PAIRS_DIR,
    negative_pairs_path=VAL_NEGATIVE_PAIRS_DIR,
    images_path=IMGS_DIR,
    input_shape=INPUT_SHAPE,
    batch_size=BATCH_SIZE,
    seed=SEED,
    shuffle=True,
    debug=True
)

TEST_POSITIVE_PAIRS_DIR = os.path.join(PAIRS_DIR, 'test_positive_pairs.csv')
TEST_NEGATIVE_PAIRS_DIR = os.path.join(PAIRS_DIR, 'test_negative_pairs.csv')

test_data = DataGenerator(
    positive_pairs_path=TEST_POSITIVE_PAIRS_DIR,
    negative_pairs_path=TEST_NEGATIVE_PAIRS_DIR,
    images_path=IMGS_DIR,
    input_shape=INPUT_SHAPE,
    batch_size=BATCH_SIZE,
    seed=SEED,
    shuffle=True,
    debug=True
)

print(f'Train data: {BATCH_SIZE * len(train_data)} samples in {len(train_data)} batches')
print(f'Validation data: {BATCH_SIZE * len(val_data)} samples in {len(val_data)} batches')
print(f'Test data: {BATCH_SIZE * len(test_data)} samples in {len(test_data)} batches')
# Out:
# Train data: 24128 samples in 754 batches
# Validation data: 3040 samples in 95 batches
# Test data: 3040 samples in 95 batches

# %%
siamese_model = get_siamese_model('ResNet50', input_shape=INPUT_SHAPE)

history = train_model(
    siamese_network=siamese_model,
    model_name='ResNet50-150-128',
    training_dataset_generator=train_data,
    validation_dataset_generator=val_data)
# Out:
# Model: "Pretrained_ResNet50"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 5, 5, 2048)        23587712
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 128)               6553728
#
# =================================================================
# Total params: 30,141,440
# Trainable params: 6,553,728
# Non-trainable params: 23,587,712
# _________________________________________________________________
# Epoch 1/50
# 754/754 [==============================] - 292s 375ms/step - loss: 0.2279 - accuracy: 0.6294 - val_loss: 0.2083 - val_accuracy: 0.6740
# Epoch 2/50
# 754/754 [==============================] - 281s 372ms/step - loss: 0.1889 - accuracy: 0.7332 - val_loss: 0.1890 - val_accuracy: 0.7257
# Epoch 3/50
# 754/754 [==============================] - 281s 373ms/step - loss: 0.1729 - accuracy: 0.7739 - val_loss: 0.1845 - val_accuracy: 0.7296
# Epoch 4/50
# 754/754 [==============================] - 281s 372ms/step - loss: 0.1631 - accuracy: 0.7973 - val_loss: 0.1784 - val_accuracy: 0.7553
# Epoch 5/50
# 754/754 [==============================] - 280s 371ms/step - loss: 0.1559 - accuracy: 0.8132 - val_loss: 0.1755 - val_accuracy: 0.7579
# Epoch 6/50
# 754/754 [==============================] - 283s 375ms/step - loss: 0.1494 - accuracy: 0.8300 - val_loss: 0.1704 - val_accuracy: 0.7724
# Epoch 7/50
# 754/754 [==============================] - 280s 371ms/step - loss: 0.1454 - accuracy: 0.8390 - val_loss: 0.1672 - val_accuracy: 0.7766
# Epoch 8/50
# 754/754 [==============================] - 281s 373ms/step - loss: 0.1418 - accuracy: 0.8477 - val_loss: 0.1650 - val_accuracy: 0.7832
# Epoch 9/50
# 754/754 [==============================] - 278s 368ms/step - loss: 0.1388 - accuracy: 0.8550 - val_loss: 0.1651 - val_accuracy: 0.7799
# Epoch 10/50
# 754/754 [==============================] - 281s 372ms/step - loss: 0.1358 - accuracy: 0.8601 - val_loss: 0.1619 - val_accuracy: 0.7924
# Epoch 11/50
# 754/754 [==============================] - 282s 373ms/step - loss: 0.1329 - accuracy: 0.8656 - val_loss: 0.1603 - val_accuracy: 0.7885
# Epoch 12/50
# 754/754 [==============================] - 282s 374ms/step - loss: 0.1307 - accuracy: 0.8716 - val_loss: 0.1593 - val_accuracy: 0.7990
# Epoch 13/50
# 754/754 [==============================] - 280s 371ms/step - loss: 0.1290 - accuracy: 0.8762 - val_loss: 0.1575 - val_accuracy: 0.8102
# Epoch 14/50
# 754/754 [==============================] - 281s 372ms/step - loss: 0.1278 - accuracy: 0.8788 - val_loss: 0.1540 - val_accuracy: 0.8168
# Epoch 15/50
# 754/754 [==============================] - 278s 368ms/step - loss: 0.1244 - accuracy: 0.8854 - val_loss: 0.1542 - val_accuracy: 0.8076
# Epoch 16/50
# 754/754 [==============================] - 276s 365ms/step - loss: 0.1237 - accuracy: 0.8885 - val_loss: 0.1546 - val_accuracy: 0.8059
# Epoch 17/50
# 754/754 [==============================] - 282s 373ms/step - loss: 0.1229 - accuracy: 0.8892 - val_loss: 0.1533 - val_accuracy: 0.8188
# Epoch 18/50
# 754/754 [==============================] - 277s 367ms/step - loss: 0.1205 - accuracy: 0.8932 - val_loss: 0.1547 - val_accuracy: 0.8099
# Epoch 19/50
# 754/754 [==============================] - 279s 370ms/step - loss: 0.1196 - accuracy: 0.8952 - val_loss: 0.1538 - val_accuracy: 0.8072
# Epoch 20/50
# 754/754 [==============================] - 280s 371ms/step - loss: 0.1189 - accuracy: 0.8948 - val_loss: 0.1501 - val_accuracy: 0.8253
# Epoch 21/50
# 754/754 [==============================] - 277s 368ms/step - loss: 0.1172 - accuracy: 0.9008 - val_loss: 0.1506 - val_accuracy: 0.8092
# Epoch 22/50
# 754/754 [==============================] - 276s 366ms/step - loss: 0.1158 - accuracy: 0.9008 - val_loss: 0.1535 - val_accuracy: 0.8132
# Epoch 23/50
# 754/754 [==============================] - 278s 368ms/step - loss: 0.1152 - accuracy: 0.9033 - val_loss: 0.1521 - val_accuracy: 0.8151
# Epoch 24/50
# 754/754 [==============================] - 280s 371ms/step - loss: 0.1144 - accuracy: 0.9057 - val_loss: 0.1490 - val_accuracy: 0.8188
# Epoch 25/50
# 754/754 [==============================] - 281s 372ms/step - loss: 0.1129 - accuracy: 0.9086 - val_loss: 0.1475 - val_accuracy: 0.8247
# Epoch 26/50
# 754/754 [==============================] - 278s 368ms/step - loss: 0.1120 - accuracy: 0.9101 - val_loss: 0.1493 - val_accuracy: 0.8191
# Epoch 27/50
# 754/754 [==============================] - 281s 372ms/step - loss: 0.1113 - accuracy: 0.9107 - val_loss: 0.1471 - val_accuracy: 0.8178
# Epoch 28/50
# 754/754 [==============================] - 278s 369ms/step - loss: 0.1098 - accuracy: 0.9152 - val_loss: 0.1477 - val_accuracy: 0.8220
# Epoch 29/50
# 754/754 [==============================] - 276s 365ms/step - loss: 0.1092 - accuracy: 0.9169 - val_loss: 0.1475 - val_accuracy: 0.8164
# Epoch 30/50
# 754/754 [==============================] - 277s 367ms/step - loss: 0.1087 - accuracy: 0.9169 - val_loss: 0.1478 - val_accuracy: 0.8151
# Epoch 31/50
# 754/754 [==============================] - 280s 372ms/step - loss: 0.1081 - accuracy: 0.9192 - val_loss: 0.1461 - val_accuracy: 0.8234
# Epoch 32/50
# 754/754 [==============================] - 277s 367ms/step - loss: 0.1070 - accuracy: 0.9211 - val_loss: 0.1462 - val_accuracy: 0.8247
# Epoch 33/50
# 754/754 [==============================] - 277s 367ms/step - loss: 0.1065 - accuracy: 0.9215 - val_loss: 0.1464 - val_accuracy: 0.8227
# Epoch 34/50
# 754/754 [==============================] - 281s 373ms/step - loss: 0.1076 - accuracy: 0.9185 - val_loss: 0.1459 - val_accuracy: 0.8240
# Epoch 35/50
# 754/754 [==============================] - 282s 374ms/step - loss: 0.1062 - accuracy: 0.9208 - val_loss: 0.1455 - val_accuracy: 0.8303
# Epoch 36/50
# 754/754 [==============================] - 277s 367ms/step - loss: 0.1056 - accuracy: 0.9235 - val_loss: 0.1463 - val_accuracy: 0.8237
# Epoch 37/50
# 754/754 [==============================] - 279s 370ms/step - loss: 0.1053 - accuracy: 0.9218 - val_loss: 0.1434 - val_accuracy: 0.8401
# Epoch 38/50
# 754/754 [==============================] - 277s 367ms/step - loss: 0.1042 - accuracy: 0.9268 - val_loss: 0.1446 - val_accuracy: 0.8276
# Epoch 39/50
# 754/754 [==============================] - 280s 371ms/step - loss: 0.1032 - accuracy: 0.9282 - val_loss: 0.1433 - val_accuracy: 0.8332
# Epoch 40/50
# 754/754 [==============================] - 280s 371ms/step - loss: 0.1028 - accuracy: 0.9281 - val_loss: 0.1420 - val_accuracy: 0.8313
# Epoch 41/50
# 754/754 [==============================] - 278s 368ms/step - loss: 0.1026 - accuracy: 0.9293 - val_loss: 0.1443 - val_accuracy: 0.8237
# Epoch 42/50
# 754/754 [==============================] - 277s 367ms/step - loss: 0.1032 - accuracy: 0.9264 - val_loss: 0.1441 - val_accuracy: 0.8299
# Epoch 43/50
# 754/754 [==============================] - 277s 366ms/step - loss: 0.1007 - accuracy: 0.9324 - val_loss: 0.1434 - val_accuracy: 0.8322
# Epoch 44/50
# 754/754 [==============================] - 278s 368ms/step - loss: 0.1006 - accuracy: 0.9312 - val_loss: 0.1435 - val_accuracy: 0.8299
# Epoch 45/50
# 754/754 [==============================] - 278s 368ms/step - loss: 0.1002 - accuracy: 0.9321 - val_loss: 0.1425 - val_accuracy: 0.8322
# Epoch 46/50
# 754/754 [==============================] - 277s 367ms/step - loss: 0.1001 - accuracy: 0.9313 - val_loss: 0.1441 - val_accuracy: 0.8270
# Epoch 47/50
# 754/754 [==============================] - 279s 370ms/step - loss: 0.1001 - accuracy: 0.9341 - val_loss: 0.1433 - val_accuracy: 0.8293
# Epoch 48/50
# 754/754 [==============================] - 280s 371ms/step - loss: 0.0995 - accuracy: 0.9339 - val_loss: 0.1419 - val_accuracy: 0.8401
# Epoch 49/50
# 754/754 [==============================] - 278s 368ms/step - loss: 0.0988 - accuracy: 0.9341 - val_loss: 0.1428 - val_accuracy: 0.8299
# Epoch 50/50
# 754/754 [==============================] - 277s 367ms/step - loss: 0.0991 - accuracy: 0.9345 - val_loss: 0.1421 - val_accuracy: 0.8382

# %%
siamese_model.evaluate(test_data)
# Out:
# 95/95 [==============================] - 29s 304ms/step - loss: 0.1421 - accuracy: 0.8378
# [0.1421089917421341, 0.8378289341926575]

# %%
import pandas as pd

hist_df = pd.DataFrame(history.history)

hist_csv_file = r'../logs/history_resnet_2009_150_128.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5, 5))
# plt.ylim([0, 0.4])
# plt.xlim([0, 51])
plt.plot(range(1, 51), history.history['loss'], label='Zbiór treningowy')
plt.plot(range(1, 51), history.history['val_loss'], label='Zbiór walidacyjny')
# plt.grid()
plt.legend(loc='upper right')
# plt.title('Model loss')
plt.ylabel('Strata kontrastowa')
plt.xlabel('Epoka')
plt.show()

plt.figure(figsize=(5, 5))
# plt.ylim([0, 1])
# plt.xlim([0, 51])
plt.plot(range(1, 51), history.history['accuracy'], label='Zbiór treningowy')
plt.plot(range(1, 51), history.history['val_accuracy'], label='Zbiór walidacyjny')
# plt.grid()
plt.legend(loc='lower right')
# plt.title('Model accuracy')
plt.ylabel('Dokładność [%]')
plt.xlabel('Epoka')
plt.show()
