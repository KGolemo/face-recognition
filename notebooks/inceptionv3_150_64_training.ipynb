# %%
import os
import sys
sys.path.append('../')
from facerec.dataset_generator import DataGenerator
from facerec.siamese_models import get_siamese_model, train_model

# %%
IMGS_DIR = r'../data/faces/'
PAIRS_DIR = r'../data/pairs/'
TRAIN_POSITIVE_PAIRS_DIR = os.path.join(PAIRS_DIR, 'train_positive_pairs.csv')
TRAIN_NEGATIVE_PAIRS_DIR = os.path.join(PAIRS_DIR, 'train_negative_pairs.csv')

SEED = 80808
BATCH_SIZE = 32
INPUT_SHAPE = (150, 150, 3)

train_data = DataGenerator(
    positive_pairs_path=TRAIN_POSITIVE_PAIRS_DIR,
    negative_pairs_path=TRAIN_NEGATIVE_PAIRS_DIR,
    images_path=IMGS_DIR,
    input_shape=INPUT_SHAPE,
    batch_size=BATCH_SIZE,
    seed=SEED,
    shuffle=True,
    debug=True
)

VAL_POSITIVE_PAIRS_DIR = os.path.join(PAIRS_DIR, 'val_positive_pairs.csv')
VAL_NEGATIVE_PAIRS_DIR = os.path.join(PAIRS_DIR, 'val_negative_pairs.csv')

val_data = DataGenerator(
    positive_pairs_path=VAL_POSITIVE_PAIRS_DIR,
    negative_pairs_path=VAL_NEGATIVE_PAIRS_DIR,
    images_path=IMGS_DIR,
    input_shape=INPUT_SHAPE,
    batch_size=BATCH_SIZE,
    seed=SEED,
    shuffle=True,
    debug=True
)

TEST_POSITIVE_PAIRS_DIR = os.path.join(PAIRS_DIR, 'test_positive_pairs.csv')
TEST_NEGATIVE_PAIRS_DIR = os.path.join(PAIRS_DIR, 'test_negative_pairs.csv')

test_data = DataGenerator(
    positive_pairs_path=TEST_POSITIVE_PAIRS_DIR,
    negative_pairs_path=TEST_NEGATIVE_PAIRS_DIR,
    images_path=IMGS_DIR,
    input_shape=INPUT_SHAPE,
    batch_size=BATCH_SIZE,
    seed=SEED,
    shuffle=True,
    debug=True
)

print(f'Train data: {BATCH_SIZE * len(train_data)} samples in {len(train_data)} batches')
print(f'Validation data: {BATCH_SIZE * len(val_data)} samples in {len(val_data)} batches')
print(f'Test data: {BATCH_SIZE * len(test_data)} samples in {len(test_data)} batches')
# Out:
# Train data: 24128 samples in 754 batches
# Validation data: 3040 samples in 95 batches
# Test data: 3040 samples in 95 batches

# %%
siamese_model = get_siamese_model('InceptionV3', input_shape=INPUT_SHAPE)

history = train_model(
    siamese_network=siamese_model,
    model_name='InceptionV3-150-64',
    training_dataset_generator=train_data,
    validation_dataset_generator=val_data)
# Out:
# Model: "Pretrained_InceptionV3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 3, 3, 2048)        21802784
#
#  flatten (Flatten)           (None, 18432)             0
#
#  dense (Dense)               (None, 64)                1179712
#
# =================================================================
# Total params: 22,982,496
# Trainable params: 1,179,712
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/50
# 754/754 [==============================] - 195s 241ms/step - loss: 0.2269 - accuracy: 0.6221 - val_loss: 0.2085 - val_accuracy: 0.6883
# Epoch 2/50
# 754/754 [==============================] - 165s 218ms/step - loss: 0.1943 - accuracy: 0.7219 - val_loss: 0.1991 - val_accuracy: 0.7006
# Epoch 3/50
# 754/754 [==============================] - 166s 219ms/step - loss: 0.1788 - accuracy: 0.7653 - val_loss: 0.1905 - val_accuracy: 0.7298
# Epoch 4/50
# 754/754 [==============================] - 164s 217ms/step - loss: 0.1686 - accuracy: 0.7915 - val_loss: 0.1863 - val_accuracy: 0.7351
# Epoch 5/50
# 754/754 [==============================] - 165s 219ms/step - loss: 0.1609 - accuracy: 0.8100 - val_loss: 0.1831 - val_accuracy: 0.7540
# Epoch 6/50
# 754/754 [==============================] - 165s 218ms/step - loss: 0.1547 - accuracy: 0.8267 - val_loss: 0.1788 - val_accuracy: 0.7606
# Epoch 7/50
# 754/754 [==============================] - 166s 220ms/step - loss: 0.1492 - accuracy: 0.8386 - val_loss: 0.1769 - val_accuracy: 0.7662
# Epoch 8/50
# 754/754 [==============================] - 165s 218ms/step - loss: 0.1446 - accuracy: 0.8501 - val_loss: 0.1738 - val_accuracy: 0.7725
# Epoch 9/50
# 754/754 [==============================] - 166s 220ms/step - loss: 0.1407 - accuracy: 0.8588 - val_loss: 0.1728 - val_accuracy: 0.7788
# Epoch 10/50
# 754/754 [==============================] - 165s 219ms/step - loss: 0.1374 - accuracy: 0.8677 - val_loss: 0.1701 - val_accuracy: 0.7815
# Epoch 11/50
# 754/754 [==============================] - 166s 220ms/step - loss: 0.1340 - accuracy: 0.8766 - val_loss: 0.1686 - val_accuracy: 0.7848
# Epoch 12/50
# 754/754 [==============================] - 165s 219ms/step - loss: 0.1309 - accuracy: 0.8811 - val_loss: 0.1669 - val_accuracy: 0.7921
# Epoch 13/50
# 754/754 [==============================] - 162s 215ms/step - loss: 0.1283 - accuracy: 0.8878 - val_loss: 0.1677 - val_accuracy: 0.7855
# Epoch 14/50
# 754/754 [==============================] - 167s 221ms/step - loss: 0.1262 - accuracy: 0.8916 - val_loss: 0.1653 - val_accuracy: 0.7931
# Epoch 15/50
# 754/754 [==============================] - 165s 218ms/step - loss: 0.1239 - accuracy: 0.8960 - val_loss: 0.1639 - val_accuracy: 0.7895
# Epoch 16/50
# 754/754 [==============================] - 165s 219ms/step - loss: 0.1220 - accuracy: 0.8995 - val_loss: 0.1633 - val_accuracy: 0.7948
# Epoch 17/50
# 754/754 [==============================] - 164s 217ms/step - loss: 0.1198 - accuracy: 0.9040 - val_loss: 0.1627 - val_accuracy: 0.7958
# Epoch 18/50
# 754/754 [==============================] - 166s 220ms/step - loss: 0.1180 - accuracy: 0.9072 - val_loss: 0.1613 - val_accuracy: 0.8047
# Epoch 19/50
# 754/754 [==============================] - 162s 214ms/step - loss: 0.1165 - accuracy: 0.9093 - val_loss: 0.1613 - val_accuracy: 0.7984
# Epoch 20/50
# 754/754 [==============================] - 165s 219ms/step - loss: 0.1145 - accuracy: 0.9133 - val_loss: 0.1604 - val_accuracy: 0.8011
# Epoch 21/50
# 754/754 [==============================] - 166s 220ms/step - loss: 0.1139 - accuracy: 0.9143 - val_loss: 0.1603 - val_accuracy: 0.8004
# Epoch 22/50
# 754/754 [==============================] - 164s 217ms/step - loss: 0.1118 - accuracy: 0.9186 - val_loss: 0.1591 - val_accuracy: 0.8004
# Epoch 23/50
# 754/754 [==============================] - 165s 219ms/step - loss: 0.1102 - accuracy: 0.9206 - val_loss: 0.1574 - val_accuracy: 0.8123
# Epoch 24/50
# 754/754 [==============================] - 165s 218ms/step - loss: 0.1092 - accuracy: 0.9223 - val_loss: 0.1573 - val_accuracy: 0.8097
# Epoch 25/50
# 754/754 [==============================] - 164s 217ms/step - loss: 0.1081 - accuracy: 0.9245 - val_loss: 0.1571 - val_accuracy: 0.8130
# Epoch 26/50
# 754/754 [==============================] - 164s 217ms/step - loss: 0.1066 - accuracy: 0.9257 - val_loss: 0.1571 - val_accuracy: 0.8100
# Epoch 27/50
# 754/754 [==============================] - 164s 218ms/step - loss: 0.1053 - accuracy: 0.9286 - val_loss: 0.1558 - val_accuracy: 0.8156
# Epoch 28/50
# 754/754 [==============================] - 165s 218ms/step - loss: 0.1043 - accuracy: 0.9297 - val_loss: 0.1546 - val_accuracy: 0.8163
# Epoch 29/50
# 754/754 [==============================] - 163s 216ms/step - loss: 0.1031 - accuracy: 0.9322 - val_loss: 0.1544 - val_accuracy: 0.8196
# Epoch 30/50
# 754/754 [==============================] - 161s 214ms/step - loss: 0.1025 - accuracy: 0.9323 - val_loss: 0.1546 - val_accuracy: 0.8196
# Epoch 31/50
# 754/754 [==============================] - 164s 218ms/step - loss: 0.1017 - accuracy: 0.9324 - val_loss: 0.1538 - val_accuracy: 0.8166
# Epoch 32/50
# 754/754 [==============================] - 165s 218ms/step - loss: 0.1004 - accuracy: 0.9354 - val_loss: 0.1532 - val_accuracy: 0.8229
# Epoch 33/50
# 754/754 [==============================] - 164s 217ms/step - loss: 0.0997 - accuracy: 0.9376 - val_loss: 0.1526 - val_accuracy: 0.8210
# Epoch 34/50
# 754/754 [==============================] - 166s 219ms/step - loss: 0.0987 - accuracy: 0.9387 - val_loss: 0.1520 - val_accuracy: 0.8249
# Epoch 35/50
# 754/754 [==============================] - 161s 213ms/step - loss: 0.0977 - accuracy: 0.9397 - val_loss: 0.1522 - val_accuracy: 0.8186
# Epoch 36/50
# 754/754 [==============================] - 161s 213ms/step - loss: 0.0972 - accuracy: 0.9421 - val_loss: 0.1526 - val_accuracy: 0.8200
# Epoch 37/50
# 754/754 [==============================] - 164s 217ms/step - loss: 0.0966 - accuracy: 0.9412 - val_loss: 0.1516 - val_accuracy: 0.8296
# Epoch 38/50
# 754/754 [==============================] - 161s 213ms/step - loss: 0.0957 - accuracy: 0.9423 - val_loss: 0.1517 - val_accuracy: 0.8236
# Epoch 39/50
# 754/754 [==============================] - 164s 217ms/step - loss: 0.0949 - accuracy: 0.9433 - val_loss: 0.1508 - val_accuracy: 0.8206
# Epoch 40/50
# 754/754 [==============================] - 164s 217ms/step - loss: 0.0942 - accuracy: 0.9440 - val_loss: 0.1502 - val_accuracy: 0.8256
# Epoch 41/50
# 754/754 [==============================] - 162s 215ms/step - loss: 0.0935 - accuracy: 0.9457 - val_loss: 0.1503 - val_accuracy: 0.8203
# Epoch 42/50
# 754/754 [==============================] - 165s 218ms/step - loss: 0.0930 - accuracy: 0.9467 - val_loss: 0.1495 - val_accuracy: 0.8299
# Epoch 43/50
# 754/754 [==============================] - 165s 218ms/step - loss: 0.0925 - accuracy: 0.9475 - val_loss: 0.1492 - val_accuracy: 0.8279
# Epoch 44/50
# 754/754 [==============================] - 162s 214ms/step - loss: 0.0917 - accuracy: 0.9478 - val_loss: 0.1493 - val_accuracy: 0.8216
# Epoch 45/50
# 754/754 [==============================] - 165s 218ms/step - loss: 0.0910 - accuracy: 0.9494 - val_loss: 0.1489 - val_accuracy: 0.8282
# Epoch 46/50
# 754/754 [==============================] - 164s 217ms/step - loss: 0.0907 - accuracy: 0.9487 - val_loss: 0.1484 - val_accuracy: 0.8273
# Epoch 47/50
# 754/754 [==============================] - 160s 212ms/step - loss: 0.0899 - accuracy: 0.9496 - val_loss: 0.1484 - val_accuracy: 0.8279
# Epoch 48/50
# 754/754 [==============================] - 162s 215ms/step - loss: 0.0894 - accuracy: 0.9511 - val_loss: 0.1489 - val_accuracy: 0.8286
# Epoch 49/50
# 754/754 [==============================] - 165s 219ms/step - loss: 0.0885 - accuracy: 0.9511 - val_loss: 0.1476 - val_accuracy: 0.8273
# Epoch 50/50
# 754/754 [==============================] - 164s 217ms/step - loss: 0.0881 - accuracy: 0.9518 - val_loss: 0.1469 - val_accuracy: 0.8282

# %%
siamese_model.evaluate(test_data)
# Out:
# 95/95 [==============================] - 17s 172ms/step - loss: 0.1457 - accuracy: 0.8415
# [0.14572027325630188, 0.8415119647979736]

# %%
import pandas as pd

hist_df = pd.DataFrame(history.history)

hist_csv_file = r'../logs/history_inception_2009_150_64.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %%
import matplotlib.pyplot as plt
import pandas as pd

history = pd.read_csv(r'../logs/history_inception_2009_150_64.csv')

plt.figure(figsize=(5, 5))
# plt.ylim([0, 0.4])
# plt.xlim([0, 51])
plt.plot(range(1, 51), history['loss'], label='Zbiór treningowy')
plt.plot(range(1, 51), history['val_loss'], label='Zbiór walidacyjny')
# plt.grid()
plt.legend(loc='upper right')
# plt.title('Model loss')
plt.ylabel('Strata kontrastowa')
plt.xlabel('Epoka')
plt.show()

plt.figure(figsize=(5, 5))
# plt.ylim([0, 1])
# plt.xlim([0, 51])
plt.plot(range(1, 51), history['accuracy'], label='Zbiór treningowy')
plt.plot(range(1, 51), history['val_accuracy'], label='Zbiór walidacyjny')
# plt.grid()
plt.legend(loc='lower right')
# plt.title('Model accuracy')
plt.ylabel('Dokładność [%]')
plt.xlabel('Epoka')
plt.show()
